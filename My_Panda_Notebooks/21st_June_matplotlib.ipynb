# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
l1 = range(6)
x = pd.Series(l1)
y = x ** 2
plt.plot(x,y,'r:')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Hello')
plt.show()

# %%
import numpy as np
import pandas as pd
unemployement_rate = pd.read_csv('/home/greyatom/unemployement_rate.csv')
unemployement_rate['DATE']

# Convert the DATE column to datetime datatype
unemployement_rate['DATE'] = pd.to_datetime(unemployement_rate['DATE'])
unemployement_rate.head(20)

# Extract dates and value of year 19849
rate_1949 = unemployement_rate[unemployement_rate['DATE'].dt.year == 1948]

plt.plot(rate_1949['DATE'],rate_1949['VALUE'],'r')
plt.xlabel('Months of 1949')
plt.ylabel('Value ')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

unemployement_rate = pd.read_csv('/home/greyatom/unemployement_rate.csv')
unemployement_rate['DATE']
fig, axes = plt.subplots(nrows=2,ncols=2)
# print dir(axes)
# Convert the DATE column to datetime datatype
unemployement_rate['DATE'] = pd.to_datetime(unemployement_rate['DATE'])
unemployement_rate.head(20)
#print unemployement_rate['DATE']
# Extract dates and value of year 19849
rate_1949 = unemployement_rate[unemployement_rate['DATE'].dt.year == 1949]
#print rate_1949
rate_1948 = unemployement_rate[unemployement_rate['DATE'].dt.year == 1948]
axes[0][1].plot(rate_1949['DATE'],rate_1949['VALUE'],'r',rate_1948['DATE'],rate_1948['VALUE'],'b')
axes[0][0].plot(rate_1949['DATE'].dt.month,rate_1949['VALUE'],'r',rate_1948['DATE'].dt.month,rate_1948['VALUE'],'b')
# Out:
# [<matplotlib.lines.Line2D at 0x7fc4a2587110>,
#  <matplotlib.lines.Line2D at 0x7fc4a2587310>]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.hist(np.random.randn(1000))
#plt.plot(np.random.randn(1000))
# Out:
# (array([  10.,   26.,   81.,  152.,  234.,  222.,  143.,   88.,   31.,   13.]),
#  array([-2.8423447 , -2.2746886 , -1.70703249, -1.13937638, -0.57172027,
#         -0.00406416,  0.56359195,  1.13124806,  1.69890416,  2.26656027,
#          2.83421638]),
#  <a list of 10 Patch objects>)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

reviews = pd.read_csv('/home/greyatom/fandango_scores.csv')
norm_reviews = reviews [['FILM','RT_user_norm','Metacritic_user_nom','IMDB_norm','Fandango_Ratingvalue','Fandango_Stars']]
norm_10 = norm_reviews.sort_values('Fandango_Ratingvalue',ascending = False).head(10)
norm_10;

my_ticks = norm_10['FILM']
fig,axes = plt.subplots()

x = range(len(norm_10))
y = norm_10['Fandango_Ratingvalue']

axes.barh(x,y,0.7)
plt.yticks(x, my_ticks)

#axes.bar(x,y,0.7)
#plt.xticks(x,my_ticks)
# Out:
# ([<matplotlib.axis.YTick at 0x7fc4a2934b10>,
#   <matplotlib.axis.YTick at 0x7fc4a29154d0>,
#   <matplotlib.axis.YTick at 0x7fc4accbdfd0>,
#   <matplotlib.axis.YTick at 0x7fc4a28c5d50>,
#   <matplotlib.axis.YTick at 0x7fc4a28534d0>,
#   <matplotlib.axis.YTick at 0x7fc4a2853c10>,
#   <matplotlib.axis.YTick at 0x7fc4a285e390>,
#   <matplotlib.axis.YTick at 0x7fc4a285ead0>,
#   <matplotlib.axis.YTick at 0x7fc4a2869250>,
#   <matplotlib.axis.YTick at 0x7fc4a2869990>],
#  <a list of 10 Text yticklabel objects>)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

reviews = pd.read_csv('/home/greyatom/fandango_scores.csv')
norm_reviews = reviews [['FILM','RT_user_norm','Metacritic_user_nom','IMDB_norm','Fandango_Ratingvalue','Fandango_Stars']]
fig,axes = plt.subplots()


x = norm_reviews['RT_user_norm']
y = norm_reviews['Fandango_Ratingvalue']

axes.scatter(x,y)

#axes.bar(x,y,0.7)
#plt.xticks(x,my_ticks)

# %%
import seaborn as sns
